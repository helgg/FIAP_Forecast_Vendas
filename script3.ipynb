# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path
from pycaret.classification import *

from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import StandardScaler

# %%
try:
    from xgboost import XGBRegressor
    XGB_AVAILABLE = True
except Exception:
    print("⚠️ XGBoost não disponível. Instale com: pip install xgboost")
    XGB_AVAILABLE = False

plt.rcParams["figure.figsize"] = (12, 4)
plt.rcParams["axes.grid"] = False

# %%
# %% utils
def mape(y_true, y_pred):
    y_true = np.array(y_true)
    y_pred = np.array(y_pred)
    eps = 1e-9
    return np.mean(np.abs((y_true - y_pred) / np.clip(y_true, eps, None))) * 100

def plot_series(dates, y_true, y_pred, title):
    plt.figure()
    plt.plot(dates, y_true, label="Real")
    plt.plot(dates, y_pred, label="Previsto")
    plt.title(title)
    plt.xlabel("Data")
    plt.ylabel("Vendas Semanais")
    plt.legend()
    plt.tight_layout()
    plt.show()

def plot_series_multi(dates, y_true, **preds):
    plt.figure()
    plt.plot(dates, y_true, label="Real")
    for name, arr in preds.items():
        plt.plot(dates, arr, label=name)
    plt.title("Real x Modelos")
    plt.xlabel("Data")
    plt.ylabel("Vendas Semanais")
    plt.legend()
    plt.tight_layout()
    plt.show()

def plot_scatter(y_true, y_pred, title):
    plt.figure()
    plt.scatter(y_true, y_pred, s=10)
    mn = min(np.min(y_true), np.min(y_pred))
    mx = max(np.max(y_true), np.max(y_pred))
    plt.plot([mn, mx], [mn, mx])
    plt.title(title)
    plt.xlabel("Real")
    plt.ylabel("Previsto")
    plt.tight_layout()
    plt.show()

def plot_error_over_time(dates, y_true, y_pred, title):
    err = np.array(y_true) - np.array(y_pred)
    plt.figure()
    plt.plot(dates, err)
    plt.title(title)
    plt.xlabel("Data")
    plt.ylabel("Erro (real - previsto)")
    plt.tight_layout()
    plt.show()

def plot_error_box_by_month(dates, y_true, y_pred, title):
    df_tmp = pd.DataFrame({
        "date": pd.to_datetime(dates),
        "err": np.array(y_true) - np.array(y_pred)
    })
    df_tmp["month"] = df_tmp["date"].dt.month
    data = [df_tmp[df_tmp["month"] == m]["err"].values for m in sorted(df_tmp["month"].unique())]
    plt.figure()
    plt.boxplot(data, labels=sorted(df_tmp["month"].unique()))
    plt.title(title)
    plt.xlabel("Mês")
    plt.ylabel("Erro")
    plt.tight_layout()
    plt.show()

def plot_feature_importance(importances, feature_names, title):
    idx = np.argsort(importances)[::-1]
    plt.figure(figsize=(10,4))
    plt.bar(range(len(idx)), np.array(importances)[idx])
    plt.xticks(range(len(idx)), np.array(feature_names)[idx], rotation=90)
    plt.title(title)
    plt.tight_layout()
    plt.show()

def iterative_forecast(model, X_test_scaled, lag_positions, scaler, original_X_test):
    Xt = X_test_scaled.copy()
    preds = []
    for i in range(Xt.shape[0]):
        p = model.predict(Xt[i].reshape(1, -1))[0]
        preds.append(p)
        if i + 1 < Xt.shape[0]:
            # vamos montar linha de referência pra escalar o novo lag
            ref = original_X_test.iloc[[i+1]].copy()
            ref["Weekly_Sales_lag_1"] = p
            ref_scaled = scaler.transform(ref.values)
            Xt[i+1, lag_positions["Weekly_Sales_lag_1"]] = ref_scaled[0, lag_positions["Weekly_Sales_lag_1"]]
    return np.array(preds)

# %%
# %% 1) carregar
DATA_PATH = Path("sales.csv")
df = pd.read_csv(DATA_PATH)
df["Date"] = pd.to_datetime(df["Date"], dayfirst=True, errors="coerce")
df = df.sort_values("Date").reset_index(drop=True)

if (df["Fuel_Price"] > 100).any():
    df["Fuel_Price"] = df["Fuel_Price"] / 1000.0
if (df["Unemployment"] > 100).any():
    df["Unemployment"] = df["Unemployment"] / 1000.0

# %%
df.head(5)
# Out:
#         Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price         CPI  \
# 0 2010-02-05    1643690.90             0        42.31       2.572  211.096358
# 1 2010-02-12    1641957.44             1        38.51       2.548  211.242170
# 2 2010-02-19    1611968.17             0        39.93       2.514  211.289143
# 3 2010-02-26    1409727.59             0        46.63       2.561  211.319643
# 4 2010-03-05    1554806.68             0        46.50       2.625  211.350143
#
#    Unemployment
# 0         8.106
# 1         8.106
# 2         8.106
# 3         8.106
# 4         8.106

# %%
s = setup(df, target='Holiday_Flag')
s
# Out:
# <style type="text/css">
# #T_985f3_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_985f3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_985f3_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_985f3_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_985f3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_985f3_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_985f3_row0_col1" class="data row0 col1" >1703</td>
#     </tr>
#     <tr>
#       <th id="T_985f3_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_985f3_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_985f3_row1_col1" class="data row1 col1" >Holiday_Flag</td>
#     </tr>
#     <tr>
#       <th id="T_985f3_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_985f3_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_985f3_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_985f3_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_985f3_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_985f3_row3_col1" class="data row3 col1" >(143, 7)</td>
#     </tr>
#     <tr>
#       <th id="T_985f3_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_985f3_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_985f3_row4_col1" class="data row4 col1" >(143, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_985f3_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_985f3_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_985f3_row5_col1" class="data row5 col1" >(100, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_985f3_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_985f3_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_985f3_row6_col1" class="data row6 col1" >(43, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_985f3_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_985f3_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_985f3_row7_col1" class="data row7 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_985f3_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_985f3_row8_col0" class="data row8 col0" >Date features</td>
#       <td id="T_985f3_row8_col1" class="data row8 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_985f3_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_985f3_row9_col0" class="data row9 col0" >Preprocess</td>
#       <td id="T_985f3_row9_col1" class="data row9 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_985f3_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_985f3_row10_col0" class="data row10 col0" >Imputation type</td>
#       <td id="T_985f3_row10_col1" class="data row10 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_985f3_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_985f3_row11_col0" class="data row11 col0" >Numeric imputation</td>
#       <td id="T_985f3_row11_col1" class="data row11 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_985f3_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_985f3_row12_col0" class="data row12 col0" >Categorical imputation</td>
#       <td id="T_985f3_row12_col1" class="data row12 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_985f3_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_985f3_row13_col0" class="data row13 col0" >Fold Generator</td>
#       <td id="T_985f3_row13_col1" class="data row13 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_985f3_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_985f3_row14_col0" class="data row14 col0" >Fold Number</td>
#       <td id="T_985f3_row14_col1" class="data row14 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_985f3_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_985f3_row15_col0" class="data row15 col0" >CPU Jobs</td>
#       <td id="T_985f3_row15_col1" class="data row15 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_985f3_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_985f3_row16_col0" class="data row16 col0" >Use GPU</td>
#       <td id="T_985f3_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_985f3_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_985f3_row17_col0" class="data row17 col0" >Log Experiment</td>
#       <td id="T_985f3_row17_col1" class="data row17 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_985f3_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_985f3_row18_col0" class="data row18 col0" >Experiment Name</td>
#       <td id="T_985f3_row18_col1" class="data row18 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_985f3_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_985f3_row19_col0" class="data row19 col0" >USI</td>
#       <td id="T_985f3_row19_col1" class="data row19 col1" >3787</td>
#     </tr>
#   </tbody>
# </table>

# %%
best = compare_models()
# Out:
# <style type="text/css">
# #T_6bd68 th {
#   text-align: left;
# }
# #T_6bd68_row0_col0, #T_6bd68_row0_col3, #T_6bd68_row0_col4, #T_6bd68_row0_col5, #T_6bd68_row0_col6, #T_6bd68_row0_col7, #T_6bd68_row1_col0, #T_6bd68_row1_col2, #T_6bd68_row1_col3, #T_6bd68_row1_col4, #T_6bd68_row1_col5, #T_6bd68_row1_col6, #T_6bd68_row1_col7, #T_6bd68_row2_col0, #T_6bd68_row2_col2, #T_6bd68_row2_col3, #T_6bd68_row2_col4, #T_6bd68_row2_col5, #T_6bd68_row2_col6, #T_6bd68_row2_col7, #T_6bd68_row3_col0, #T_6bd68_row3_col2, #T_6bd68_row3_col3, #T_6bd68_row3_col4, #T_6bd68_row3_col5, #T_6bd68_row3_col6, #T_6bd68_row3_col7, #T_6bd68_row4_col0, #T_6bd68_row4_col2, #T_6bd68_row4_col3, #T_6bd68_row4_col4, #T_6bd68_row4_col5, #T_6bd68_row4_col6, #T_6bd68_row4_col7, #T_6bd68_row5_col0, #T_6bd68_row5_col2, #T_6bd68_row5_col3, #T_6bd68_row5_col4, #T_6bd68_row5_col5, #T_6bd68_row5_col6, #T_6bd68_row5_col7, #T_6bd68_row6_col0, #T_6bd68_row6_col1, #T_6bd68_row6_col2, #T_6bd68_row6_col3, #T_6bd68_row6_col4, #T_6bd68_row6_col5, #T_6bd68_row6_col6, #T_6bd68_row6_col7, #T_6bd68_row7_col0, #T_6bd68_row7_col1, #T_6bd68_row7_col2, #T_6bd68_row7_col3, #T_6bd68_row7_col4, #T_6bd68_row7_col5, #T_6bd68_row7_col6, #T_6bd68_row7_col7, #T_6bd68_row8_col0, #T_6bd68_row8_col1, #T_6bd68_row8_col2, #T_6bd68_row8_col3, #T_6bd68_row8_col4, #T_6bd68_row8_col5, #T_6bd68_row8_col6, #T_6bd68_row8_col7, #T_6bd68_row9_col0, #T_6bd68_row9_col1, #T_6bd68_row9_col2, #T_6bd68_row9_col3, #T_6bd68_row9_col4, #T_6bd68_row9_col5, #T_6bd68_row9_col6, #T_6bd68_row9_col7, #T_6bd68_row10_col0, #T_6bd68_row10_col1, #T_6bd68_row10_col2, #T_6bd68_row10_col3, #T_6bd68_row10_col4, #T_6bd68_row10_col5, #T_6bd68_row10_col6, #T_6bd68_row10_col7, #T_6bd68_row11_col0, #T_6bd68_row11_col1, #T_6bd68_row11_col2, #T_6bd68_row11_col3, #T_6bd68_row11_col4, #T_6bd68_row11_col5, #T_6bd68_row11_col6, #T_6bd68_row11_col7, #T_6bd68_row12_col0, #T_6bd68_row12_col1, #T_6bd68_row12_col2, #T_6bd68_row12_col6, #T_6bd68_row13_col0, #T_6bd68_row13_col1, #T_6bd68_row13_col2, #T_6bd68_row13_col3, #T_6bd68_row13_col4, #T_6bd68_row13_col5, #T_6bd68_row13_col6, #T_6bd68_row13_col7, #T_6bd68_row14_col0, #T_6bd68_row14_col1, #T_6bd68_row14_col2, #T_6bd68_row14_col3, #T_6bd68_row14_col4, #T_6bd68_row14_col5, #T_6bd68_row14_col6, #T_6bd68_row14_col7 {
#   text-align: left;
# }
# #T_6bd68_row0_col1, #T_6bd68_row0_col2, #T_6bd68_row1_col1, #T_6bd68_row2_col1, #T_6bd68_row3_col1, #T_6bd68_row4_col1, #T_6bd68_row5_col1, #T_6bd68_row12_col3, #T_6bd68_row12_col4, #T_6bd68_row12_col5, #T_6bd68_row12_col7 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_6bd68_row0_col8, #T_6bd68_row1_col8, #T_6bd68_row2_col8, #T_6bd68_row3_col8, #T_6bd68_row4_col8, #T_6bd68_row6_col8, #T_6bd68_row7_col8, #T_6bd68_row8_col8, #T_6bd68_row9_col8, #T_6bd68_row10_col8, #T_6bd68_row12_col8, #T_6bd68_row13_col8, #T_6bd68_row14_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_6bd68_row5_col8, #T_6bd68_row11_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_6bd68">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6bd68_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_6bd68_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_6bd68_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_6bd68_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_6bd68_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_6bd68_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_6bd68_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_6bd68_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_6bd68_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6bd68_level0_row0" class="row_heading level0 row0" >knn</th>
#       <td id="T_6bd68_row0_col0" class="data row0 col0" >K Neighbors Classifier</td>
#       <td id="T_6bd68_row0_col1" class="data row0 col1" >0.9300</td>
#       <td id="T_6bd68_row0_col2" class="data row0 col2" >0.4667</td>
#       <td id="T_6bd68_row0_col3" class="data row0 col3" >0.0000</td>
#       <td id="T_6bd68_row0_col4" class="data row0 col4" >0.0000</td>
#       <td id="T_6bd68_row0_col5" class="data row0 col5" >0.0000</td>
#       <td id="T_6bd68_row0_col6" class="data row0 col6" >nan</td>
#       <td id="T_6bd68_row0_col7" class="data row0 col7" >0.0000</td>
#       <td id="T_6bd68_row0_col8" class="data row0 col8" >0.1210</td>
#     </tr>
#     <tr>
#       <th id="T_6bd68_level0_row1" class="row_heading level0 row1" >svm</th>
#       <td id="T_6bd68_row1_col0" class="data row1 col0" >SVM - Linear Kernel</td>
#       <td id="T_6bd68_row1_col1" class="data row1 col1" >0.9300</td>
#       <td id="T_6bd68_row1_col2" class="data row1 col2" >0.2222</td>
#       <td id="T_6bd68_row1_col3" class="data row1 col3" >0.0000</td>
#       <td id="T_6bd68_row1_col4" class="data row1 col4" >0.0000</td>
#       <td id="T_6bd68_row1_col5" class="data row1 col5" >0.0000</td>
#       <td id="T_6bd68_row1_col6" class="data row1 col6" >nan</td>
#       <td id="T_6bd68_row1_col7" class="data row1 col7" >0.0000</td>
#       <td id="T_6bd68_row1_col8" class="data row1 col8" >0.0440</td>
#     </tr>
#     <tr>
#       <th id="T_6bd68_level0_row2" class="row_heading level0 row2" >rf</th>
#       <td id="T_6bd68_row2_col0" class="data row2 col0" >Random Forest Classifier</td>
#       <td id="T_6bd68_row2_col1" class="data row2 col1" >0.9300</td>
#       <td id="T_6bd68_row2_col2" class="data row2 col2" >0.4333</td>
#       <td id="T_6bd68_row2_col3" class="data row2 col3" >0.0000</td>
#       <td id="T_6bd68_row2_col4" class="data row2 col4" >0.0000</td>
#       <td id="T_6bd68_row2_col5" class="data row2 col5" >0.0000</td>
#       <td id="T_6bd68_row2_col6" class="data row2 col6" >nan</td>
#       <td id="T_6bd68_row2_col7" class="data row2 col7" >0.0000</td>
#       <td id="T_6bd68_row2_col8" class="data row2 col8" >0.2170</td>
#     </tr>
#     <tr>
#       <th id="T_6bd68_level0_row3" class="row_heading level0 row3" >qda</th>
#       <td id="T_6bd68_row3_col0" class="data row3 col0" >Quadratic Discriminant Analysis</td>
#       <td id="T_6bd68_row3_col1" class="data row3 col1" >0.9300</td>
#       <td id="T_6bd68_row3_col2" class="data row3 col2" >0.3556</td>
#       <td id="T_6bd68_row3_col3" class="data row3 col3" >0.0000</td>
#       <td id="T_6bd68_row3_col4" class="data row3 col4" >0.0000</td>
#       <td id="T_6bd68_row3_col5" class="data row3 col5" >0.0000</td>
#       <td id="T_6bd68_row3_col6" class="data row3 col6" >nan</td>
#       <td id="T_6bd68_row3_col7" class="data row3 col7" >0.0000</td>
#       <td id="T_6bd68_row3_col8" class="data row3 col8" >0.0500</td>
#     </tr>
#     <tr>
#       <th id="T_6bd68_level0_row4" class="row_heading level0 row4" >xgboost</th>
#       <td id="T_6bd68_row4_col0" class="data row4 col0" >Extreme Gradient Boosting</td>
#       <td id="T_6bd68_row4_col1" class="data row4 col1" >0.9300</td>
#       <td id="T_6bd68_row4_col2" class="data row4 col2" >0.4000</td>
#       <td id="T_6bd68_row4_col3" class="data row4 col3" >0.0000</td>
#       <td id="T_6bd68_row4_col4" class="data row4 col4" >0.0000</td>
#       <td id="T_6bd68_row4_col5" class="data row4 col5" >0.0000</td>
#       <td id="T_6bd68_row4_col6" class="data row4 col6" >nan</td>
#       <td id="T_6bd68_row4_col7" class="data row4 col7" >0.0000</td>
#       <td id="T_6bd68_row4_col8" class="data row4 col8" >0.0620</td>
#     </tr>
#     <tr>
#       <th id="T_6bd68_level0_row5" class="row_heading level0 row5" >dummy</th>
#       <td id="T_6bd68_row5_col0" class="data row5 col0" >Dummy Classifier</td>
#       <td id="T_6bd68_row5_col1" class="data row5 col1" >0.9300</td>
#       <td id="T_6bd68_row5_col2" class="data row5 col2" >0.3500</td>
#       <td id="T_6bd68_row5_col3" class="data row5 col3" >0.0000</td>
#       <td id="T_6bd68_row5_col4" class="data row5 col4" >0.0000</td>
#       <td id="T_6bd68_row5_col5" class="dat

# %%
modelx = compare_models(n_select = 5)
# Out:
# <style type="text/css">
# #T_ff222 th {
#   text-align: left;
# }
# #T_ff222_row0_col0, #T_ff222_row0_col3, #T_ff222_row0_col4, #T_ff222_row0_col5, #T_ff222_row0_col6, #T_ff222_row0_col7, #T_ff222_row1_col0, #T_ff222_row1_col2, #T_ff222_row1_col3, #T_ff222_row1_col4, #T_ff222_row1_col5, #T_ff222_row1_col6, #T_ff222_row1_col7, #T_ff222_row2_col0, #T_ff222_row2_col2, #T_ff222_row2_col3, #T_ff222_row2_col4, #T_ff222_row2_col5, #T_ff222_row2_col6, #T_ff222_row2_col7, #T_ff222_row3_col0, #T_ff222_row3_col2, #T_ff222_row3_col3, #T_ff222_row3_col4, #T_ff222_row3_col5, #T_ff222_row3_col6, #T_ff222_row3_col7, #T_ff222_row4_col0, #T_ff222_row4_col2, #T_ff222_row4_col3, #T_ff222_row4_col4, #T_ff222_row4_col5, #T_ff222_row4_col6, #T_ff222_row4_col7, #T_ff222_row5_col0, #T_ff222_row5_col2, #T_ff222_row5_col3, #T_ff222_row5_col4, #T_ff222_row5_col5, #T_ff222_row5_col6, #T_ff222_row5_col7, #T_ff222_row6_col0, #T_ff222_row6_col1, #T_ff222_row6_col2, #T_ff222_row6_col3, #T_ff222_row6_col4, #T_ff222_row6_col5, #T_ff222_row6_col6, #T_ff222_row6_col7, #T_ff222_row7_col0, #T_ff222_row7_col1, #T_ff222_row7_col2, #T_ff222_row7_col3, #T_ff222_row7_col4, #T_ff222_row7_col5, #T_ff222_row7_col6, #T_ff222_row7_col7, #T_ff222_row8_col0, #T_ff222_row8_col1, #T_ff222_row8_col2, #T_ff222_row8_col3, #T_ff222_row8_col4, #T_ff222_row8_col5, #T_ff222_row8_col6, #T_ff222_row8_col7, #T_ff222_row9_col0, #T_ff222_row9_col1, #T_ff222_row9_col2, #T_ff222_row9_col3, #T_ff222_row9_col4, #T_ff222_row9_col5, #T_ff222_row9_col6, #T_ff222_row9_col7, #T_ff222_row10_col0, #T_ff222_row10_col1, #T_ff222_row10_col2, #T_ff222_row10_col3, #T_ff222_row10_col4, #T_ff222_row10_col5, #T_ff222_row10_col6, #T_ff222_row10_col7, #T_ff222_row11_col0, #T_ff222_row11_col1, #T_ff222_row11_col2, #T_ff222_row11_col3, #T_ff222_row11_col4, #T_ff222_row11_col5, #T_ff222_row11_col6, #T_ff222_row11_col7, #T_ff222_row12_col0, #T_ff222_row12_col1, #T_ff222_row12_col2, #T_ff222_row12_col6, #T_ff222_row13_col0, #T_ff222_row13_col1, #T_ff222_row13_col2, #T_ff222_row13_col3, #T_ff222_row13_col4, #T_ff222_row13_col5, #T_ff222_row13_col6, #T_ff222_row13_col7, #T_ff222_row14_col0, #T_ff222_row14_col1, #T_ff222_row14_col2, #T_ff222_row14_col3, #T_ff222_row14_col4, #T_ff222_row14_col5, #T_ff222_row14_col6, #T_ff222_row14_col7 {
#   text-align: left;
# }
# #T_ff222_row0_col1, #T_ff222_row0_col2, #T_ff222_row1_col1, #T_ff222_row2_col1, #T_ff222_row3_col1, #T_ff222_row4_col1, #T_ff222_row5_col1, #T_ff222_row12_col3, #T_ff222_row12_col4, #T_ff222_row12_col5, #T_ff222_row12_col7 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_ff222_row0_col8, #T_ff222_row1_col8, #T_ff222_row2_col8, #T_ff222_row3_col8, #T_ff222_row4_col8, #T_ff222_row6_col8, #T_ff222_row7_col8, #T_ff222_row8_col8, #T_ff222_row9_col8, #T_ff222_row10_col8, #T_ff222_row11_col8, #T_ff222_row12_col8, #T_ff222_row13_col8, #T_ff222_row14_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_ff222_row5_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_ff222">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ff222_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_ff222_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_ff222_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_ff222_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_ff222_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_ff222_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_ff222_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_ff222_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_ff222_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ff222_level0_row0" class="row_heading level0 row0" >knn</th>
#       <td id="T_ff222_row0_col0" class="data row0 col0" >K Neighbors Classifier</td>
#       <td id="T_ff222_row0_col1" class="data row0 col1" >0.9300</td>
#       <td id="T_ff222_row0_col2" class="data row0 col2" >0.4667</td>
#       <td id="T_ff222_row0_col3" class="data row0 col3" >0.0000</td>
#       <td id="T_ff222_row0_col4" class="data row0 col4" >0.0000</td>
#       <td id="T_ff222_row0_col5" class="data row0 col5" >0.0000</td>
#       <td id="T_ff222_row0_col6" class="data row0 col6" >nan</td>
#       <td id="T_ff222_row0_col7" class="data row0 col7" >0.0000</td>
#       <td id="T_ff222_row0_col8" class="data row0 col8" >0.0680</td>
#     </tr>
#     <tr>
#       <th id="T_ff222_level0_row1" class="row_heading level0 row1" >svm</th>
#       <td id="T_ff222_row1_col0" class="data row1 col0" >SVM - Linear Kernel</td>
#       <td id="T_ff222_row1_col1" class="data row1 col1" >0.9300</td>
#       <td id="T_ff222_row1_col2" class="data row1 col2" >0.2222</td>
#       <td id="T_ff222_row1_col3" class="data row1 col3" >0.0000</td>
#       <td id="T_ff222_row1_col4" class="data row1 col4" >0.0000</td>
#       <td id="T_ff222_row1_col5" class="data row1 col5" >0.0000</td>
#       <td id="T_ff222_row1_col6" class="data row1 col6" >nan</td>
#       <td id="T_ff222_row1_col7" class="data row1 col7" >0.0000</td>
#       <td id="T_ff222_row1_col8" class="data row1 col8" >0.0540</td>
#     </tr>
#     <tr>
#       <th id="T_ff222_level0_row2" class="row_heading level0 row2" >rf</th>
#       <td id="T_ff222_row2_col0" class="data row2 col0" >Random Forest Classifier</td>
#       <td id="T_ff222_row2_col1" class="data row2 col1" >0.9300</td>
#       <td id="T_ff222_row2_col2" class="data row2 col2" >0.4333</td>
#       <td id="T_ff222_row2_col3" class="data row2 col3" >0.0000</td>
#       <td id="T_ff222_row2_col4" class="data row2 col4" >0.0000</td>
#       <td id="T_ff222_row2_col5" class="data row2 col5" >0.0000</td>
#       <td id="T_ff222_row2_col6" class="data row2 col6" >nan</td>
#       <td id="T_ff222_row2_col7" class="data row2 col7" >0.0000</td>
#       <td id="T_ff222_row2_col8" class="data row2 col8" >0.2690</td>
#     </tr>
#     <tr>
#       <th id="T_ff222_level0_row3" class="row_heading level0 row3" >qda</th>
#       <td id="T_ff222_row3_col0" class="data row3 col0" >Quadratic Discriminant Analysis</td>
#       <td id="T_ff222_row3_col1" class="data row3 col1" >0.9300</td>
#       <td id="T_ff222_row3_col2" class="data row3 col2" >0.3556</td>
#       <td id="T_ff222_row3_col3" class="data row3 col3" >0.0000</td>
#       <td id="T_ff222_row3_col4" class="data row3 col4" >0.0000</td>
#       <td id="T_ff222_row3_col5" class="data row3 col5" >0.0000</td>
#       <td id="T_ff222_row3_col6" class="data row3 col6" >nan</td>
#       <td id="T_ff222_row3_col7" class="data row3 col7" >0.0000</td>
#       <td id="T_ff222_row3_col8" class="data row3 col8" >0.0540</td>
#     </tr>
#     <tr>
#       <th id="T_ff222_level0_row4" class="row_heading level0 row4" >xgboost</th>
#       <td id="T_ff222_row4_col0" class="data row4 col0" >Extreme Gradient Boosting</td>
#       <td id="T_ff222_row4_col1" class="data row4 col1" >0.9300</td>
#       <td id="T_ff222_row4_col2" class="data row4 col2" >0.4000</td>
#       <td id="T_ff222_row4_col3" class="data row4 col3" >0.0000</td>
#       <td id="T_ff222_row4_col4" class="data row4 col4" >0.0000</td>
#       <td id="T_ff222_row4_col5" class="data row4 col5" >0.0000</td>
#       <td id="T_ff222_row4_col6" class="data row4 col6" >nan</td>
#       <td id="T_ff222_row4_col7" class="data row4 col7" >0.0000</td>
#       <td id="T_ff222_row4_col8" class="data row4 col8" >0.0570</td>
#     </tr>
#     <tr>
#       <th id="T_ff222_level0_row5" class="row_heading level0 row5" >dummy</th>
#       <td id="T_ff222_row5_col0" class="data row5 col0" >Dummy Classifier</td>
#       <td id="T_ff222_row5_col1" class="data row5 col1" >0.9300</td>
#       <td id="T_ff222_row5_col2" class="data row5 col2" >0.3500</td>
#       <td id="T_ff222_row5_col3" class="data row5 col3" >0.0000</td>
#       <td id="T_ff222_row5_col4" class="data row5 col4" >0.0000</td>
#       <td id="T_ff222_row5_col5" class="dat

# %%
evaluate_model(modelx[1])
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
# %% 2) feature engineering
df["year"] = df["Date"].dt.year
df["month"] = df["Date"].dt.month
df["weekofyear"] = df["Date"].dt.isocalendar().week.astype(int)
df["quarter"] = df["Date"].dt.quarter
df["is_month_start"] = df["Date"].dt.is_month_start.astype(int)
df["is_month_end"] = df["Date"].dt.is_month_end.astype(int)
df["month_sin"] = np.sin(2 * np.pi * df["month"] / 12)
df["month_cos"] = np.cos(2 * np.pi * df["month"] / 12)

# %%
# lags
for lag in [1, 2, 3, 4, 12, 52]:
    df[f"Weekly_Sales_lag_{lag}"] = df["Weekly_Sales"].shift(lag)

# %%
# rolling (deslocando 1 pra não vazar)
df["Weekly_Sales_roll_4"] = df["Weekly_Sales"].rolling(4).mean().shift(1)
df["Weekly_Sales_roll_12"] = df["Weekly_Sales"].rolling(12).mean().shift(1)

# %%
# descarta início com NaN
df = df.dropna().reset_index(drop=True)

# %%
# %% 3) split temporal
cutoff = pd.Timestamp("2012-01-01")
train_df = df[df["Date"] < cutoff].copy()
test_df  = df[df["Date"] >= cutoff].copy()

# %%
target = "Weekly_Sales"
feature_cols = [
    "Holiday_Flag","Temperature","Fuel_Price","CPI","Unemployment",
    "year","month","weekofyear","quarter",
    "is_month_start","is_month_end",
    "month_sin","month_cos",
    "Weekly_Sales_lag_1","Weekly_Sales_lag_2","Weekly_Sales_lag_3",
    "Weekly_Sales_lag_4","Weekly_Sales_lag_12","Weekly_Sales_lag_52",
    "Weekly_Sales_roll_4","Weekly_Sales_roll_12"
]

X_train = train_df[feature_cols].copy()
y_train = train_df[target].copy()
X_test  = test_df[feature_cols].copy()
y_test  = test_df[target].copy()

# %%
# %% 4) scale
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train.values)
X_test_scaled  = scaler.transform(X_test.values)

# %%
# posições dos lags (pra atualizar no iterativo)
lag_positions = {col: feature_cols.index(col) for col in feature_cols if "lag_" in col}

# %%
# %% 5) modelos
rf = RandomForestRegressor(
    n_estimators=700,
    max_depth=14,
    min_samples_leaf=2,
    random_state=42,
    n_jobs=-1
)
rf.fit(X_train_scaled, y_train)

xgb_model = None
if XGB_AVAILABLE:
    xgb_model = XGBRegressor(
        n_estimators=800,
        learning_rate=0.05,
        max_depth=6,
        subsample=0.8,
        colsample_bytree=0.8,
        random_state=42,
        n_jobs=-1
    )
    xgb_model.fit(X_train_scaled, y_train)

# %%
# %% 6) forecast iterativo
pred_rf = iterative_forecast(
    model=rf,
    X_test_scaled=X_test_scaled,
    lag_positions=lag_positions,
    scaler=scaler,
    original_X_test=X_test
)

pred_xgb = None
if xgb_model is not None:
    pred_xgb = iterative_forecast(
        model=xgb_model,
        X_test_scaled=X_test_scaled,
        lag_positions=lag_positions,
        scaler=scaler,
        original_X_test=X_test
    )

# %%
# %% 7) métricas
results = [{
    "Modelo": "RandomForest_V2",
    "RMSE": np.sqrt(mean_squared_error(y_test, pred_rf)),
    "R2": r2_score(y_test, pred_rf),
    "MAPE": mape(y_test, pred_rf)
}]
if pred_xgb is not None:
    results.append({
        "Modelo": "XGBoost_V2",
        "RMSE": np.sqrt(mean_squared_error(y_test, pred_xgb)),
        "R2": r2_score(y_test, pred_xgb),
        "MAPE": mape(y_test, pred_xgb)
    })

metrics_df = pd.DataFrame(results)
print(metrics_df)
# Out:
#             Modelo          RMSE        R2      MAPE
# 0  RandomForest_V2  75076.544800  0.564276  3.434496
# 1       XGBoost_V2  92337.465289  0.340888  4.219404

# %%
# %% 8) gráficos de comparação
dates_test = test_df["Date"]

# 8.1 — cada modelo separado
plot_series(dates_test, y_test.values, pred_rf, "Real vs Previsto — RandomForest (V2)")
if pred_xgb is not None:
    plot_series(dates_test, y_test.values, pred_xgb, "Real vs Previsto — XGBoost (V2)")

# 8.2 — comparação no mesmo gráfico
if pred_xgb is not None:
    plot_series_multi(
        dates_test,
        y_test.values,
        RF_V2=pred_rf,
        XGB_V2=pred_xgb
    )

# 8.3 — scatter
plot_scatter(y_test.values, pred_rf, "Dispersão — RF_V2")
if pred_xgb is not None:
    plot_scatter(y_test.values, pred_xgb, "Dispersão — XGB_V2")

# 8.4 — erro ao longo do tempo
plot_error_over_time(dates_test, y_test.values, pred_rf, "Erro ao longo do tempo — RF_V2")
if pred_xgb is not None:
    plot_error_over_time(dates_test, y_test.values, pred_xgb, "Erro ao longo do tempo — XGB_V2")

# 8.5 — boxplot por mês
plot_error_box_by_month(dates_test, y_test.values, pred_rf, "Erro por mês — RF_V2")
if pred_xgb is not None:
    plot_error_box_by_month(dates_test, y_test.values, pred_xgb, "Erro por mês — XGB_V2")

# 8.6 — importância de features
plot_feature_importance(rf.feature_importances_, feature_cols, "Importância de Features — RF_V2")
if xgb_model is not None:
    plot_feature_importance(xgb_model.feature_importances_, feature_cols, "Importância de Features — XGB_V2")
# Out:
# C:\Users\helde\AppData\Local\Temp\ipykernel_11808\3134459514.py:61: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(data, labels=sorted(df_tmp["month"].unique()))
# C:\Users\helde\AppData\Local\Temp\ipykernel_11808\3134459514.py:61: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(data, labels=sorted(df_tmp["month"].unique()))

# %%
df.iloc[1][0]
# Out:
# C:\Users\helde\AppData\Local\Temp\ipykernel_11808\1019881219.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df.iloc[1][0]
# Timestamp('2011-02-11 00:00:00')
